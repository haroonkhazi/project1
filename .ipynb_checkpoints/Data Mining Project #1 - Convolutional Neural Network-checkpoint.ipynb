# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# Load in the data using pandas read_csv function as a dataframe
train_data = pd.read_csv('training.csv')

# %%
# For convolutional neural networks, the labels need to be one hot-encoded
# The pixel values for the black-and-white images range from 0 to 255
# so the values need to be scaled between 0 and 1 as floats.
# Additionally, the Conv2D layer requires a 3-D image as input because it deals with color images
# The images in this dataset are black-and-white 2-D images, but can be converted to a pseudo 3-D 
# image by adding a third dimension of 1
labelsData = train_data['label']
onehotData = keras.utils.to_categorical(labelsData, 10)
# Convert pandas data frame to numpy array
imgData = train_data.drop(['label'], axis=1).values
# Reshape into a 21000x28x28x1 matrix
imgData = imgData.reshape(21000, 28, 28, 1)
# Rescale pixel values
imgData = imgData / 255.0
# Sample image
plt.imshow(imgData[0].reshape(28, 28), cmap='gray')

# %%
smpSize = (28, 28, 1)

# %%
# Function to create model, required for KerasClassifier
def create_model(Conv2D_size, kernel_size_conv, activation_func, pool_size_conv):
    model = Sequential()
    model.add(Conv2D(Conv2D_size, kernel_size=kernel_size_conv, activation=activation_func, input_shape=smpSize))
    model.add(MaxPooling2D(pool_size=pool_size_conv))
    model.add(Flatten())
    model.add(Dense(10, activation='softmax'))

    model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), 
             metrics=['accuracy'])
    return model

#model.fit(imgData[:10000], onehotData[:10000], validation_data=(imgData[10000:], onehotData[10000:]), batch_size=128, epochs=3, verbose=1)

# %%
import sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score
from keras.wrappers.scikit_learn import KerasClassifier

np.random.seed(1)
model = KerasClassifier(build_fn=create_model, batch_size=128, epochs=3)
param_grid = dict(kernel_size_conv=[(3, 3), (6, 6), (2, 2), (12, 12)], epochs=[3, 6], Conv2D_size=[32, 64],
                 activation_func=['relu', 'tanh'], pool_size_conv=[(2,2), (4, 4)])
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=-1, cv=3)
grid_result = grid.fit(imgData, onehotData, verbose=1)
# Out:
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\externals\joblib\externals\loky\process_executor.py:706: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   "timeout or by a memory leak.", UserWarning
# Epoch 1/6
# 21000/21000 [==============================] - 59s 3ms/step - loss: 0.4293 - acc: 0.8748
# Epoch 2/6
# 21000/21000 [==============================] - 70s 3ms/step - loss: 0.1353 - acc: 0.9607
# Epoch 3/6
# 21000/21000 [==============================] - 71s 3ms/step - loss: 0.0915 - acc: 0.9730
# Epoch 4/6
# 21000/21000 [==============================] - 74s 4ms/step - loss: 0.0692 - acc: 0.9799
# Epoch 5/6
# 21000/21000 [==============================] - 71s 3ms/step - loss: 0.0587 - acc: 0.9822
# Epoch 6/6
# 21000/21000 [==============================] - 76s 4ms/step - loss: 0.0489 - acc: 0.9863

# %%
pd.DataFrame(grid_result.cv_results_)
# Out:
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      220.307498      0.221953        15.686763        0.122996
# 1      189.120104      3.359264        15.845209        0.354651
# 2      281.462422      4.949427        22.143997        0.105160
# 3      258.015838      0.198919        21.929181        0.144685
# 4      182.965083      2.259866        12.585904        0.611224
# 5      158.989128      2.193872        10.970759        0.520896
# 6      361.134112      1.603547        25.660483        0.407363
# 7      362.839985     10.196703        26.703555        0.416385
# 8      409.119721     13.338193        17.047057        0.210427
# 9      379.409705      0.903749        16.307535        0.339797
# 10     548.788514      1.195527        21.752052        0.212521
# 11     517.605790      2.528578        22.402178        0.527039
# 12     360.737165      4.994061        12.379089        0.173817
# 13     312.575431      1.082931        11.362369        0.538979
# 14     717.338735      4.179781        26.090455        0.378687
# 15     711.326482     15.180717        26.584805        0.743333
# 16     200.107879      1.443651        17.429327        0.115346
# 17     175.783004      1.263959        16.603411        0.310080
# 18     276.174683      1.568020        23.394881        1.142999
# 19     258.034184      1.149128        23.415231        0.869075
# 20     180.356239      0.541795        14.100975        0.408601
# 21     158.573831      1.291323        13.980557        1.013279
# 22     364.431444      3.046096        26.804626        0.555134
# 23     365.798410     10.833262        27.256947        1.324820
# 24     403.100462     11.725472        18.903704        0.305763
# 25     373.473839      2.024398        18.532775        1.987700
# 26     552.840379      3.896523        23.563668        1.078536
# 27     514.726421      3.293446        24.942307        1.632499
# 28     353.736547      1.304323        14.427203        0.298366
# 29     307.759692      1.225475        13.772407        0.529752
# ..            ...           ...              ...             ...
# 34     410.339916      4.335808        30.057594        1.080746
# 35     371.750621      0.697880        28.364729        0.243709
# 36     331.840057      3.365841        18.580811        0.259319
# 37     287.181802      1.360327        16.471650        0.347522
# 38     497.726728      2.410841        34.925704        0.230889
# 39     492.676490      7.632658        34.961063        0.918370
# 40     707.687243     16.244035        24.101380        0.943604
# 41     626.528503      0.661923        21.820766        0.511095
# 42     825.412514      6.525509        30.947224        0.201638
# 43     745.378570      1.533515        28.578213        0.921289
# 44     663.078355      3.773844        17.837284        0.555413
# 45     585.537507      1.804864        16.621090        0.907930
# 46     983.853919      3.174654        35.411382        0.995286
# 47     978.576852     13.420917        35.474760        0.615231
# 48     340.604589      1.116259        25.471017        0.657434
# 49     291.451822      2.844889        24.400259        0.544901
# 50     412.655887      1.193625        32.470968        1.110293
# 51     375.002920      1.087999        31.148367        1.102375
# 52     335.658424      1.021888        21.034546        0.259707
# 53     291.752702      0.837502        20.247655        0.672930
# 54     501.338284      1.204813        35.759293        0.459748
# 55     507.233454     15.886192        37.218325        1.457850
# 56     704.834224     15.213069        28.478476        0.674030
# 57     623.108751      3.963353        24.889270        0.840474
# 58     830.520460      4.767389        32.396248        1.122088
# 59     755.083434      1.213970        31.779812        1.221276
# 60     660.431482      7.879901        22.001564        0.740972
# 61     578.881132      3.490393        21.239023        0.579061
# 62     997.226377      2.364202        36.011471        0.576604
# 63     755.736560    148.599533        28.894439        4.759386
#
#    param_Conv2D_size param_activation_func param_epochs  \
# 0                 32                  relu            3
# 1                 32                  relu            3
# 2                 32                  relu            3
# 3                 32                  relu            3
# 4                 32                  relu            3
# 5                 32                  relu            3
# 6                 32                  relu            3
# 7                 32                  relu            3
# 8                 32                  relu            6
# 9                 32                  relu            6
# 10                32                  relu            6
# 11                32                  relu            6
# 12                32                  relu            6
# 13                32                  relu            6
# 14                32                  relu            6
# 15                32                  relu            6
# 16                32                  tanh            3
# 17                32                  tanh            3
# 18                32                  tanh            3
# 19                32                  tanh            3
# 20                32                  tanh            3
# 21                32                  tanh            3
# 22                32                  tanh            3
# 23                32                  tanh            3
# 24                32                  tanh            6
# 25                32                  tanh            6
# 26                32                  tanh            6
# 27                32                  tanh            6
# 28                32                  tanh            6
# 29                32                  tanh            6
# ..               ...                   ...          ...
# 34                64                  relu            3
# 35                64                  relu            3
# 36                64                  relu            3
# 37                64                  relu            3
# 38                64                  relu            3
# 39                64                  relu            3
# 40                64                  relu            6
# 41                64                  relu            6
# 42                64                  relu            6
# 43                64                  relu            6
# 44                64                  relu            6
# 45                64                  relu            6
# 46                64                  relu            6
# 47                64                  relu            6
# 48                64                  tanh            3
# 49                64                  tanh            3
# 50                64                  tanh            3
# 51                64                  tanh            3
# 52                64                  tanh            3
# 53                64                  tanh            3
# 54                64                  tanh            3
# 55                64                  tanh            3
# 56                64                  tanh            6
# 57                64                  tanh            6
# 58                64                  tanh            6
# 59                64                  tanh            6
# 60                64                  tanh            6
# 61                64                  tanh            6
# 62                64                  tanh            6
# 63                64                  tanh            6
#
#    param_kernel_size_conv param_pool_size_conv  \
# 0                  (3, 3)               (2, 2)
# 1                  (3, 3)               (4, 4)
# 2                  (6, 6)               (2, 2)
# 3                  (6, 6)               (4, 4)
# 4                  (2, 2)               (2, 2)
# 5                  (2, 2)               (4, 4)
# 6                (12, 12)               (2, 2)
# 7                (12, 12)               (4, 4)
# 8                  (3, 3)               (2, 2)
# 9                  (3, 3)               (4, 4)
# 10                 (6, 6)               (2, 2)
# 11                 (6, 6)               (4, 4)
# 12                 (2, 2)               (2, 2)
# 13                 (2, 2)               (4, 4)
# 14               (12, 12)               (2, 2)
# 15               (12, 12)               (4, 4)
# 16                 (3, 3)               (2, 2)
# 17                 (3, 3)               (4, 4)
# 18                 (6, 6)               (2, 2)
# 19                 (6, 6)               (4, 4)
# 20                 (2, 2)               (2, 2)
# 21                 (2, 2)               (4, 4)
# 22               (12, 12)               (2, 2)
# 23               (12, 12)               (4, 4)
# 24                 (3, 3)               (2, 2)
# 25                 (3, 3)               (4, 4)
# 26                 (6, 6)               (2, 2)
# 27                 (6, 6)               (4, 4)
# 28                 (2, 2)               (2, 2)
# 29                 (2, 2)               (4, 4)
# ..                    ...                  ...
# 34                 (6, 6)               (2, 2)
# 35                 (6, 6)               (4, 4)
# 36                 (2, 2)               (2, 2)
# 37                 (2, 2)               (4, 4)
# 38               (12, 12)               (2, 2)
# 39               (12, 12)               (4, 4)
# 40                 (3, 3)               (2, 2)
# 41                 (3, 3)               (4, 4)
# 42                 (6, 6)               (2, 2)
# 43                 (6, 6)               (4, 4)
# 44                 (2, 2)               (2, 2)
# 45                 (2, 2)               (4, 4)
# 46               (12, 12)               (2, 2)
# 47               (12, 12)               (4, 4)
# 48                 (3, 3)               (2, 2)
# 49                 (3, 3)               (4, 4)
# 50                 (6, 6)               (2, 2)
# 51                 (6, 6)               (4, 4)
# 52                 (2, 2)               (2, 2)
# 53                 (2, 2)               (4, 4)
# 54               (12, 12)               (2, 2)
# 55               (12, 12)               (4, 4)
# 56                 (3, 3)               (2, 2)
# 57                 (3, 3)               (4, 4)
# 58                 (6, 6)               (2, 2)
# 59                 (6, 6)               (4, 4)
# 60                 (2, 2)               (2, 2)
# 61                 (2, 2)               (4, 4)
# 62               (12, 12)               (2, 2)
# 63               (12, 12)               (4, 4)
#
#                                                params  ...  split1_test_score  \
# 0   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.930714
# 1   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.922857
# 2   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.958714
# 3   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.950143
# 4   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.919429
# 5   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.874000
# 6   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.958000
# 7   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.930714
# 8   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.954000
# 9   {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.950857
# 10  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.974000
# 11  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.963000
# 12  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.932429
# 13  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.935857
# 14  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.973714
# 15  {'Conv2D_size': 32, 'activation_func': 'relu',...  ...           0.965143
# 16  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.926286
# 17  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.930143
# 18  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.936857
# 19  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.949286
# 20  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.915857
# 21  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.927571
# 22  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.934286
# 23  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.950714
# 24  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.934571
# 25  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.951857
# 26  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.954143
# 27  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.966571
# 28  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.927571
# 29  {'Conv2D_size': 32, 'activation_func': 'tanh',...  ...           0.934429
# ..                                                ...  ...                ...
# 34  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.965857
# 35  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.945571
# 36  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.912286
# 37  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.917857
# 38  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.964286
# 39  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.960143
# 40  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.966571
# 41  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.961714
# 42  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.971143
# 43  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.971143
# 44  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.947286
# 45  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.932000
# 46  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.974286
# 47  {'Conv2D_size': 64, 'activation_func': 'relu',...  ...           0.968286
# 48  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.934714
# 49  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.943000
# 50  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.945143
# 51  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.955143
# 52  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.920286
# 53  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.914714
# 54  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.941857
# 55  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.962286
# 56  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.940571
# 57  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.962286
# 58  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.966857
# 59  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.971286
# 60  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.931286
# 61  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.947000
# 62  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.960000
# 63  {'Conv2D_size': 64, 'activation_func': 'tanh',...  ...           0.973143
#
#     split2_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0            0.928571         0.933286        0.005226               48
# 1            0.939286         0.933286        0.007402               49
# 2            0.958286         0.952143        0.008992               29
# 3            0.940714         0.947524        0.004858               34
# 4            0.919143         0.919857        0.000816               58
# 5            0.896000         0.883714        0.009164               64
# 6            0.958571         0.956381        0.002704               24
# 7            0.950714         0.944762        0.009972               36
# 8            0.957571         0.957905        0.003333               21
# 9            0.953429         0.951190        0.001708               32
# 10           0.971429         0.972905        0.001084                3
# 11           0.961000         0.962905        0.001518               15
# 12           0.924286         0.932476        0.006707               50
# 13           0.936000         0.934429        0.002122               46
# 14           0.971571         0.970524        0.003122                6
# 15           0.967714         0.967524        0.001871               10
# 16           0.916571         0.920190        0.004335               57
# 17           0.937714         0.936238        0.004497               43
# 18           0.932857         0.930667        0.006147               52
# 19           0.956143         0.952000        0.002976               30
# 20           0.917857         0.917952        0.001751               60
# 21           0.885286         0.905476        0.017316               62
# 22           0.933714         0.932190        0.002570               51
# 23           0.952857         0.954333        0.003708               27
# 24           0.934571         0.936238        0.002357               44
# 25           0.950857         0.951286        0.000421               31
# 26           0.957571         0.956667        0.001808               23
# 27           0.967429         0.966714        0.000535               11
# 28           0.924286         0.923667        0.003469               55
# 29           0.939286         0.933714        0.004867               47
# ..                ...              ...             ...              ...
# 34           0.968286         0.964857        0.003285               12
# 35           0.953714         0.952333        0.005053               28
# 36           0.924857         0.922429        0.007490               56
# 37           0.869286         0.904857        0.025455               63
# 38           0.953000         0.960524        0.005320               20
# 39           0.961143         0.955571        0.007184               25
# 40           0.964857         0.964619        0.001700               13
# 41           0.960714         0.961048        0.000471               18
# 42           0.974000         0.972333        0.001214                4
# 43           0.966000         0.969000        0.002185                9
# 44           0.930857         0.941952        0.007847               40
# 45           0.940286         0.936190        0.003383               45
# 46           0.972857         0.974429        0.001345                1
# 47           0.973143         0.972238        0.002928                5
# 48           0.929429         0.928952        0.004911               54
# 49           0.940714         0.943190        0.002104               37
# 50           0.937857         0.942857        0.003540               39
# 51           0.958571         0.957619        0.001766               22
# 52           0.869857         0.906333        0.026029               61
# 53           0.912571         0.918429        0.006824               59
# 54           0.939857         0.940000        0.001462               41
# 55           0.962571         0.962095        0.000486               16
# 56           0.939143         0.943000        0.004483               38
# 57           0.959857         0.961429        0.001113               17
# 58           0.961857         0.964429        0.002044               14
# 59           0.969429         0.970429        0.000765                8
# 60           0.921429         0.929143        0.005632               53
# 61           0.948000         0.947714        0.000508               33
# 62           0.958571         0.960571        0.001910               19
# 63           0.977286         0.973000        0.003559                2
#
#     split0_train_score  split1_train_score  split2_train_score  \
# 0             0.942000            0.938429            0.939429
# 1             0.937643            0.931286            0.941786
# 2             0.941143            0.965786            0.967643
# 3             0.955143            0.954214            0.942357
# 4             0.925786            0.925571            0.931000
# 5             0.887357            0.878857            0.899214
# 6             0.955714            0.966000            0.963000
# 7             0.955429            0.936357            0.956714
# 8             0.971571            0.963857            0.972071
# 9             0.952571            0.959429            0.959500
# 10            0.982643            0.983357            0.981357
# 11            0.970357            0.967714            0.968857
# 12            0.948357            0.943143            0.940214
# 13            0.934286            0.941000            0.939714
# 14            0.974214            0.983714            0.981714
# 15            0.976071            0.976643            0.974929
# 16            0.921786            0.936071            0.930571
# 17            0.942000            0.936714            0.941429
# 18            0.928357            0.946571            0.945571
# 19            0.954857            0.955643            0.960071
# 20            0.928143            0.928714            0.931071
# 21            0.902786            0.932571            0.895000
# 22            0.930071            0.940071            0.941929
# 23            0.961571            0.958286            0.958286
# 24            0.952500            0.949643            0.948929
# 25            0.956143            0.958000            0.957143
# 26            0.969357            0.966071            0.972143
# 27            0.972929            0.971071            0.975571
# 28            0.930929            0.944286            0.941286
# 29            0.933357            0.942500            0.947286
# ..                 ...                 ...                 ...
# 34            0.964786            0.973000            0.976571
# 35            0.961214            0.948571            0.960429
# 36            0.934857            0.917000            0.934929
# 37            0.928571            0.924286            0.871071
# 38            0.968571            0.971714            0.955000
# 39            0.949357            0.967929            0.967571
# 40            0.974786            0.979143            0.978857
# 41            0.968071            0.970071            0.968071
# 42            0.977929            0.983000            0.987857
# 43            0.977786            0.975571            0.974429
# 44            0.959214            0.956286            0.947786
# 45            0.944429            0.942286            0.946714
# 46            0.984071            0.982714            0.983357
# 47            0.980214            0.980286            0.983143
# 48            0.931786            0.946857            0.942357
# 49            0.950143            0.949429            0.945500
# 50            0.952214            0.958786            0.951714
# 51            0.964429            0.962643            0.964643
# 52            0.936643            0.929786            0.878071
# 53            0.931429            0.921429            0.924857
# 54            0.946214            0.952714            0.949429
# 55            0.965857            0.967643            0.968214
# 56            0.962786            0.956571            0.959071
# 57            0.968429            0.969643            0.968214
# 58            0.976571            0.975429            0.979857
# 59            0.978643            0.975786            0.977357
# 60            0.950429            0.945143            0.938857
# 61            0.957357            0.954643            0.955500
# 62            0.972643            0.967643            0.970071
# 63            0.979571            0.983500            0.986714
#
#     mean_train_score  std_train_score
# 0           0.939952         0.001504
# 1           0.936905         0.004318
# 2           0.958190         0.012078
# 3           0.950571         0.005821
# 4           0.927452         0.002510
# 5           0.888476         0.008348
# 6           0.961571         0.004319
# 7           0.949500         0.009308
# 8           0.969167         0.003760
# 9           0.957167         0.003249
# 10          0.982452         0.000828
# 11          0.968976         0.001082
# 12          0.943905         0.003368
# 13          0.938333         0.002910
# 14          0.979881         0.004089
# 15          0.975881         0.000713
# 16          0.929476         0.005883
# 17          0.940048         0.002369
# 18          0.940167         0.008361
# 19          0.956857         0.002295
# 20          0.929310         0.001268
# 21          0.910119         0.016191
# 22          0.937357         0.005207
# 23          0.959381         0.001549
# 24          0.950357         0.001543
# 25          0.957095         0.000759
# 26          0.969190         0.002481
# 27          0.973190         0.001846
# 28          0.938833         0.005722
# 29          0.941048         0.005778
# ..               ...              ...
# 34          0.971452         0.004934
# 35          0.956738         0.005784
# 36          0.928929         0.008435
# 37          0.907976         0.026154
# 38          0.965095         0.007253
# 39          0.961619         0.008672
# 40          0.977595         0.001990
# 41          0.968738         0.000943
# 42          0.982929         0.004054
# 43          0.975929         0.001394
# 44          0.954429         0.004847
# 45          0.944476         0.001808
# 46          0.983381         0.000554
# 47          0.981214         0.001364
# 48          0.940333         0.006317
# 49          0.948357         0.002041
# 50          0.954238         0.003222
# 51          0.963905         0.000897
# 52          0.914833         0.026145
# 53          0.925905         0.004149
# 54          0.949452         0.002654
# 55          0.967238         0.001004
# 56          0.959476         0.002553
# 57          0.968762         0.000629
# 58          0.977286         0.001877
# 59          0.977262         0.001168
# 60          0.944810         0.004730
# 61          0.955833         0.001133
# 62          0.970119         0.002042
# 63          0.983262         0.002921
#
# [64 rows x 21 columns]

# %%
grid_result.best_params_
# Out:
# {'Conv2D_size': 64,
#  'activation_func': 'relu',
#  'epochs': 6,
#  'kernel_size_conv': (12, 12),
#  'pool_size_conv': (2, 2)}

# %%
grid_result.best_score_
# Out:
# 0.9744285714512779
