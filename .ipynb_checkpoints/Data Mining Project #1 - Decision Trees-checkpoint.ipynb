# %%
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier

# %%
train_data = pd.read_csv('Project 1 Data\\training.csv')

# %%
labels = train_data['label']
imgData = train_data.drop(['label'], axis=1).values

# %%
tree_clf = DecisionTreeClassifier(max_depth=5, max_features=748)
tree_clf.fit(imgData[:14000], labels[:14000])
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=5,
#             max_features=748, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
from sklearn.metrics import accuracy_score

label_pred = tree_clf.predict(imgData[14000:])
accuracy_score(np.array(labels[14000:]), label_pred)
# Out:
# 0.6737142857142857

# %%
from sklearn.model_selection import GridSearchCV

np.random.seed(1)

param_grid = {'criterion': ['gini', 'entropy'], 'max_depth': [2, 4, 8, 16, 32, 64, 128], 'max_features': [748],
             'min_samples_leaf': [2, 3, 10], 'min_samples_split':[2, 3, 10], 'splitter': ['best', 'random']}

decision_tree_classifier = DecisionTreeClassifier()

grid_search = GridSearchCV(decision_tree_classifier, param_grid, cv = 3, scoring='accuracy')

grid_search.fit(imgData, labels)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best'),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'criterion': ['gini', 'entropy'], 'max_depth': [2, 4, 8, 16, 32, 64, 128], 'max_features': [748], 'min_samples_leaf': [2, 3, 10], 'min_samples_split': [2, 3, 10], 'splitter': ['best', 'random']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
pd.DataFrame(grid_search.cv_results_)
# Out:
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\Pramith\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         2.278277      0.705021         0.036026        0.002451
# 1         1.097109      0.063682         0.031356        0.002056
# 2         2.519448      1.086955         0.056041        0.019813
# 3         3.185586      0.825181         0.079056        0.006688
# 4         3.720632      0.014456         0.075387        0.004112
# 5         2.661216      0.156762         0.073052        0.002161
# 6         3.951794      0.146255         0.087730        0.006604
# 7         2.776964      0.243130         0.076722        0.006554
# 8         3.422420      0.198872         0.075054        0.006170
# 9         2.292955      0.111042         0.066715        0.003301
# 10        3.414746      0.221273         0.074720        0.006950
# 11        2.181543      0.022242         0.065713        0.004502
# 12        3.361378      0.265933         0.071384        0.005441
# 13        2.509442      0.101847         0.080724        0.008963
# 14        3.827706      0.367531         0.078056        0.007794
# 15        2.588831      0.105529         0.074720        0.006133
# 16        2.942748      0.084505         0.061378        0.002358
# 17        2.147184      0.064577         0.075723        0.010282
# 18        4.309047      0.927772         0.051036        0.013376
# 19        1.701537      0.135113         0.029354        0.003302
# 20        5.593624      0.545283         0.076722        0.003773
# 21        3.249631      0.061604         0.066715        0.003861
# 22        5.369799      0.498448         0.076054        0.006688
# 23        3.238624      0.196596         0.068049        0.002831
# 24        5.286405      0.301822         0.065714        0.004112
# 25        3.141222      0.138751         0.065380        0.006133
# 26        5.220693      0.461522         0.066714        0.004500
# 27        3.182251      0.133948         0.066713        0.004646
# 28        5.096938      0.248597         0.064046        0.007263
# 29        3.066502      0.052892         0.062379        0.001701
# ..             ...           ...              ...             ...
# 222      14.835160      3.990713         0.056040        0.019456
# 223       3.992823      1.118543         0.047367        0.017926
# 224      16.969003      5.070183         0.074720        0.002056
# 225       4.631275      1.016079         0.050369        0.015531
# 226      15.638062      5.644327         0.069717        0.005253
# 227       5.522906      0.171452         0.069383        0.004787
# 228      11.069495      3.234214         0.046367        0.014646
# 229       5.126626      0.141560         0.066047        0.002946
# 230      18.626841      0.620560         0.070385        0.002359
# 231       5.237038      0.163745         0.070050        0.000817
# 232      12.562553      3.952998         0.055707        0.020285
# 233       4.980856      0.063001         0.062378        0.014278
# 234      13.100933      3.656695         0.054705        0.020086
# 235       3.810362      0.865347         0.051704        0.014066
# 236      13.494211      2.526172         0.042697        0.015639
# 237       3.209603      0.785385         0.044699        0.023173
# 238      12.217976      1.610654         0.057708        0.020432
# 239       2.631194      0.560356         0.031022        0.005358
# 240      13.544247      4.217661         0.059376        0.025056
# 241       3.369384      1.531509         0.050035        0.020557
# 242      14.673045      4.711738         0.057374        0.018638
# 243       5.646328      0.303115         0.071384        0.006605
# 244      21.044219      0.414839         0.072051        0.001634
# 245       3.934115      1.246865         0.047368        0.015596
# 246      10.488419      3.701136         0.043365        0.017338
# 247       3.027141      0.812697         0.043031        0.015265
# 248       9.809272      1.526550         0.036359        0.009984
# 249       3.052159      0.669480         0.045700        0.018221
# 250       8.591744      1.349879         0.038362        0.018169
# 251       2.407370      0.864191         0.041029        0.022776
#
#     param_criterion param_max_depth param_max_features param_min_samples_leaf  \
# 0              gini               2                748                      2
# 1              gini               2                748                      2
# 2              gini               2                748                      2
# 3              gini               2                748                      2
# 4              gini               2                748                      2
# 5              gini               2                748                      2
# 6              gini               2                748                      3
# 7              gini               2                748                      3
# 8              gini               2                748                      3
# 9              gini               2                748                      3
# 10             gini               2                748                      3
# 11             gini               2                748                      3
# 12             gini               2                748                     10
# 13             gini               2                748                     10
# 14             gini               2                748                     10
# 15             gini               2                748                     10
# 16             gini               2                748                     10
# 17             gini               2                748                     10
# 18             gini               4                748                      2
# 19             gini               4                748                      2
# 20             gini               4                748                      2
# 21             gini               4                748                      2
# 22             gini               4                748                      2
# 23             gini               4                748                      2
# 24             gini               4                748                      3
# 25             gini               4                748                      3
# 26             gini               4                748                      3
# 27             gini               4                748                      3
# 28             gini               4                748                      3
# 29             gini               4                748                      3
# ..              ...             ...                ...                    ...
# 222         entropy              64                748                      3
# 223         entropy              64                748                      3
# 224         entropy              64                748                      3
# 225         entropy              64                748                      3
# 226         entropy              64                748                      3
# 227         entropy              64                748                      3
# 228         entropy              64                748                     10
# 229         entropy              64                748                     10
# 230         entropy              64                748                     10
# 231         entropy              64                748                     10
# 232         entropy              64                748                     10
# 233         entropy              64                748                     10
# 234         entropy             128                748                      2
# 235         entropy             128                748                      2
# 236         entropy             128                748                      2
# 237         entropy             128                748                      2
# 238         entropy             128                748                      2
# 239         entropy             128                748                      2
# 240         entropy             128                748                      3
# 241         entropy             128                748                      3
# 242         entropy             128                748                      3
# 243         entropy             128                748                      3
# 244         entropy             128                748                      3
# 245         entropy             128                748                      3
# 246         entropy             128                748                     10
# 247         entropy             128                748                     10
# 248         entropy             128                748                     10
# 249         entropy             128                748                     10
# 250         entropy             128                748                     10
# 251         entropy             128                748                     10
#
#     param_min_samples_split param_splitter  ... split1_test_score  \
# 0                         2           best  ...          0.339094
# 1                         2         random  ...          0.329096
# 2                         3           best  ...          0.339094
# 3                         3         random  ...          0.331238
# 4                        10           best  ...          0.332524
# 5                        10         random  ...          0.324525
# 6                         2           best  ...          0.339094
# 7                         2         random  ...          0.327810
# 8                         3           best  ...          0.339094
# 9                         3         random  ...          0.328382
# 10                       10           best  ...          0.339094
# 11                       10         random  ...          0.339094
# 12                        2           best  ...          0.339094
# 13                        2         random  ...          0.328667
# 14                        3           best  ...          0.332524
# 15                        3         random  ...          0.348807
# 16                       10           best  ...          0.339094
# 17                       10         random  ...          0.329667
# 18                        2           best  ...          0.560634
# 19                        2         random  ...          0.554207
# 20                        3           best  ...          0.560777
# 21                        3         random  ...          0.567348
# 22                       10           best  ...          0.570061
# 23                       10         random  ...          0.567205
# 24                        2           best  ...          0.560634
# 25                        2         random  ...          0.556063
# 26                        3           best  ...          0.560634
# 27                        3         random  ...          0.567205
# 28                       10           best  ...          0.559492
# 29                       10         random  ...          0.569633
# ..                      ...            ...  ...               ...
# 222                       2           best  ...          0.829881
# 223                       2         random  ...          0.819597
# 224                       3           best  ...          0.835595
# 225                       3         random  ...          0.824168
# 226                      10           best  ...          0.830881
# 227                      10         random  ...          0.816455
# 228                       2           best  ...          0.827453
# 229                       2         random  ...          0.796886
# 230                       3           best  ...          0.822311
# 231                       3         random  ...          0.812027
# 232                      10           best  ...          0.822597
# 233                      10         random  ...          0.819169
# 234                       2           best  ...          0.828882
# 235                       2         random  ...          0.813170
# 236                       3           best  ...          0.828310
# 237                       3         random  ...          0.822740
# 238                      10           best  ...          0.820883
# 239                      10         random  ...          0.817740
# 240                       2           best  ...          0.832310
# 241                       2         random  ...          0.815741
# 242                       3           best  ...          0.832310
# 243                       3         random  ...          0.823168
# 244                      10           best  ...          0.829453
# 245                      10         random  ...          0.824025
# 246                       2           best  ...          0.820169
# 247                       2         random  ...          0.810741
# 248                       3           best  ...          0.822597
# 249                       3         random  ...          0.811027
# 250                      10           best  ...          0.818740
# 251                      10         random  ...          0.803885
#
#      split2_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0             0.343817         0.338810        0.004207              227
# 1             0.336669         0.332143        0.003263              242
# 2             0.343817         0.338810        0.004207              227
# 3             0.340386         0.339381        0.006279              226
# 4             0.343817         0.336619        0.005103              236
# 5             0.332952         0.327619        0.003785              246
# 6             0.343817         0.338810        0.004207              227
# 7             0.330236         0.327190        0.002773              247
# 8             0.343817         0.338810        0.004207              227
# 9             0.316798         0.325048        0.005866              248
# 10            0.343817         0.338810        0.004207              227
# 11            0.332523         0.332619        0.005248              241
# 12            0.343817         0.338810        0.004207              227
# 13            0.330522         0.333905        0.006140              240
# 14            0.343817         0.342524        0.007692              224
# 15            0.322087         0.336095        0.010945              239
# 16            0.343817         0.338810        0.004207              227
# 17            0.331665         0.331190        0.001102              243
# 18            0.560972         0.569143        0.011790              198
# 19            0.576126         0.567857        0.009725              203
# 20            0.560257         0.568952        0.011926              199
# 21            0.540386         0.560762        0.014696              209
# 22            0.560114         0.572000        0.010578              193
# 23            0.540815         0.558238        0.012315              212
# 24            0.560972         0.569381        0.012127              197
# 25            0.566119         0.566286        0.008415              204
# 26            0.545675         0.564048        0.016560              206
# 27            0.555826         0.559714        0.005298              211
# 28            0.560686         0.568524        0.011934              200
# 29            0.561687         0.553857        0.016999              215
# ..                 ...              ...             ...              ...
# 222           0.820300         0.825571        0.003969               16
# 223           0.822588         0.823667        0.003839               25
# 224           0.819871         0.828857        0.006611                1
# 225           0.815297         0.821619        0.004496               44
# 226           0.825590         0.826905        0.002865                9
# 227           0.825876         0.818571        0.005311               70
# 228           0.819157         0.825714        0.004801               15
# 229           0.801001         0.802476        0.005270              152
# 230           0.819728         0.823048        0.003054               30
# 231           0.811008         0.812524        0.001482              124
# 232           0.817012         0.821762        0.003584               43
# 233           0.809578         0.813333        0.004183              116
# 234           0.825447         0.827381        0.001435                6
# 235           0.818013         0.817619        0.003483               78
# 236           0.818585         0.825143        0.004636               18
# 237           0.811008         0.818238        0.005161               74
# 238           0.818585         0.822952        0.004645               32
# 239           0.820014         0.820905        0.003013               49
# 240           0.822016         0.828857        0.004835                1
# 241           0.820157         0.819571        0.002918               57
# 242           0.817584         0.826381        0.006342               11
# 243           0.818156         0.822857        0.003716               35
# 244           0.823874         0.828381        0.003327                4
# 245           0.824732         0.822952        0.002036               32
# 246           0.812294         0.821286        0.007832               48
# 247           0.812437         0.812952        0.002048              121
# 248           0.816583         0.823143        0.005588               28
# 249           0.802287         0.809429        0.005297              129
# 250           0.817298         0.819381        0.002013               59
# 251           0.803288         0.807190        0.005100              137
#
#      split0_train_score  split1_train_score  split2_train_score  \
# 0              0.333381            0.344810            0.344163
# 1              0.329737            0.333738            0.333738
# 2              0.333381            0.344810            0.344163
# 3              0.346813            0.339667            0.342021
# 4              0.333381            0.340810            0.344163
# 5              0.323450            0.326166            0.330168
# 6              0.333381            0.344810            0.344163
# 7              0.322521            0.331095            0.328597
# 8              0.333381            0.344810            0.344163
# 9              0.328665            0.333452            0.319886
# 10             0.333381            0.344810            0.344163
# 11             0.326308            0.337881            0.330096
# 12             0.333381            0.344810            0.344163
# 13             0.341526            0.331667            0.328240
# 14             0.351672            0.340810            0.344163
# 15             0.333953            0.355097            0.321956
# 16             0.333381            0.344810            0.344163
# 17             0.328451            0.333667            0.330239
# 18             0.596242            0.570326            0.564798
# 19             0.574950            0.556540            0.582649
# 20             0.596242            0.570255            0.565155
# 21             0.571663            0.581256            0.542449
# 22             0.596242            0.578970            0.564370
# 23             0.565376            0.566683            0.539236
# 24             0.596313            0.570326            0.564798
# 25             0.573164            0.559326            0.572795
# 26             0.596242            0.570326            0.554088
# 27             0.556445            0.570755            0.557658
# 28             0.595241            0.567826            0.565084
# 29             0.535296            0.569826            0.575937
# ..                  ...                 ...                 ...
# 222            0.959917            0.961212            0.960514
# 223            0.947699            0.948925            0.947662
# 224            0.960060            0.961640            0.959157
# 225            0.946056            0.947639            0.943306
# 226            0.946127            0.948925            0.946662
# 227            0.929980            0.928281            0.928026
# 228            0.897828            0.898993            0.895680
# 229            0.873535            0.864276            0.869761
# 230            0.896613            0.896207            0.896466
# 231            0.872035            0.871705            0.874116
# 232            0.902043            0.896850            0.896323
# 233            0.863890            0.872419            0.872617
# 234            0.974278            0.974498            0.975295
# 235            0.967705            0.964140            0.963799
# 236            0.975422            0.975641            0.975509
# 237            0.965419            0.965212            0.966655
# 238            0.951558            0.950211            0.948590
# 239            0.934338            0.933638            0.937737
# 240            0.958274            0.960926            0.959943
# 241            0.945127            0.947782            0.944448
# 242            0.960131            0.962069            0.959229
# 243            0.947842            0.949425            0.948447
# 244            0.945913            0.947068            0.944877
# 245            0.931909            0.930566            0.932167
# 246            0.898185            0.895993            0.895037
# 247            0.872464            0.870419            0.871117
# 248            0.901258            0.894564            0.895466
# 249            0.870749            0.869134            0.869689
# 250            0.897614            0.896564            0.895109
# 251            0.873107            0.870134            0.866619
#
#      mean_train_score  std_train_score
# 0            0.340785         0.005242
# 1            0.332404         0.001886
# 2            0.340785         0.005242
# 3            0.342834         0.002974
# 4            0.339451         0.004505
# 5            0.326595         0.002759
# 6            0.340785         0.005242
# 7            0.327404         0.003601
# 8            0.340785         0.005242
# 9            0.327334         0.005618
# 10           0.340785         0.005242
# 11           0.331428         0.004818
# 12           0.340785         0.005242
# 13           0.333811         0.005632
# 14           0.345548         0.004541
# 15           0.337002         0.013700
# 16           0.340785         0.005242
# 17           0.330786         0.002164
# 18           0.577122         0.013707
# 19           0.571380         0.010954
# 20           0.577217         0.013612
# 21           0.565123         0.016504
# 22           0.579861         0.013027
# 23           0.557098         0.012642
# 24           0.577146         0.013740
# 25           0.568428         0.006438
# 26           0.573552         0.017360
# 27           0.561619         0.006479
# 28           0.576051         0.013616
# 29           0.560353         0.017893
# ..                ...              ...
# 222          0.960548         0.000529
# 223          0.948095         0.000587
# 224          0.960286         0.001026
# 225          0.945667         0.001790
# 226          0.947238         0.001213
# 227          0.928762         0.000867
# 228          0.897500         0.001372
# 229          0.869191         0.003802
# 230          0.896429         0.000168
# 231          0.872619         0.001067
# 232          0.898405         0.002582
# 233          0.869642         0.004068
# 234          0.974690         0.000437
# 235          0.965215         0.001766
# 236          0.975524         0.000090
# 237          0.965762         0.000637
# 238          0.950119         0.001213
# 239          0.935238         0.001790
# 240          0.959714         0.001095
# 241          0.945786         0.001438
# 242          0.960476         0.001185
# 243          0.948571         0.000652
# 244          0.945953         0.000895
# 245          0.931548         0.000702
# 246          0.896405         0.001318
# 247          0.871333         0.000848
# 248          0.897096         0.002966
# 249          0.869857         0.000670
# 250          0.896429         0.001027
# 251          0.869953         0.002652
#
# [252 rows x 22 columns]

# %%
grid_search.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 64,
#  'max_features': 748,
#  'min_samples_leaf': 3,
#  'min_samples_split': 3,
#  'splitter': 'best'}
